# %% [markdown]
# <a href="https://colab.research.google.com/github/jonepyo/myproject/blob/main/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import unittest
import base64
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("https://raw.githubusercontent.com/jonepyo/myproject/main/superbowl.csv")

# %%
df
# Out:
#            Date            SB  ...             City       State
# 0    Feb 2 2020      LIV (54)  ...    Miami Gardens     Florida
# 1    Feb 3 2019     LIII (53)  ...          Atlanta     Georgia
# 2    Feb 4 2018      LII (52)  ...      Minneapolis   Minnesota
# 3    Feb 5 2017       LI (51)  ...          Houston       Texas
# 4    Feb 7 2016            50  ...      Santa Clara  California
# 5    Feb 1 2015     XLIX (49)  ...         Glendale     Arizona
# 6    Feb 2 2014   XLVIII (48)  ...  East Rutherford  New Jersey
# 7    Feb 3 2013    XLVII (47)  ...      New Orleans   Louisiana
# 8    Feb 5 2012     XLVI (46)  ...     Indianapolis     Indiana
# 9    Feb 6 2011      XLV (45)  ...        Arlington       Texas
# 10   Feb 7 2010     XLIV (44)  ...    Miami Gardens     Florida
# 11   Feb 1 2009    XLIII (43)  ...            Tampa     Florida
# 12   Feb 3 2008     XLII (42)  ...         Glendale     Arizona
# 13   Feb 4 2007      XLI (41)  ...    Miami Gardens     Florida
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        54 non-null     object
#  1   SB          54 non-null     object
#  2   Winner      54 non-null     object
#  3   Winner Pts  54 non-null     int64
#  4   Loser       54 non-null     object
#  5   Loser Pts   54 non-null     int64
#  6   MVP         54 non-null     object
#  7   Stadium     54 non-null     object
#  8   City        54 non-null     object
#  9   State       54 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 4.3+ KB

# %%
df.head()
# Out:
#          Date         SB  ...           City       State
# 0  Feb 2 2020   LIV (54)  ...  Miami Gardens     Florida
# 1  Feb 3 2019  LIII (53)  ...        Atlanta     Georgia
# 2  Feb 4 2018   LII (52)  ...    Minneapolis   Minnesota
# 3  Feb 5 2017    LI (51)  ...        Houston       Texas
# 4  Feb 7 2016         50  ...    Santa Clara  California
#
# [5 rows x 10 columns]

# %%
num_rows = df.shape[0]
num_cols = df.shape[1]
print(num_rows)
print(num_cols)
# Out:
# 54
# 10

# %%
fig1 = px.pie(df, names = 'Winner', title = 'Number of wins', width = 800, height = 700)
fig1
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9f033663-a9c3-4578-a4e0-4e5e52aae230" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f033663-a9c3-4578-a4e0-4e5e52aae230")) {
#                     Plotly.newPlot(
#                         '9f033663-a9c3-4578-a4e0-4e5e52aae230',
# ...

# %%
fig2 = px.bar(df, x = 'Winner', y = 'Winner Pts', title = 'Winner by Points')
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a4e4a9e9-1eaa-4f98-8e8f-79ae41a0e191" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a4e4a9e9-1eaa-4f98-8e8f-79ae41a0e191")) {
#                     Plotly.newPlot(
#                         'a4e4a9e9-1eaa-4f98-8e8f-79ae41a0e191',
# ...
